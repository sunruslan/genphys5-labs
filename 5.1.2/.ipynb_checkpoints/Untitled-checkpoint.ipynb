# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
# Загрузим данные
data = pd.read_csv('dataset.txt', header=None, sep=' ')
data.columns=('$%s,%s$'%(r'\theta', 'град.'), '$%s$'%(r'N' +u', номер канала'), '$%s$'%u'Счет', '$%s$'%u'Время', '$%s$'%u'Частиц')
data
# Out:
#     $\theta,  град.$  $N, номер канала$  $Счет$  $Время$  $Частиц$
# 0                  0                968   48389       63    496698
# 1                 10                892  184781      249   1662281
# 2                 20                826   64742      188    127348
# 3                 30                773   46800      173     75751
# 4                 40                713   43475      189     66609
# 5                 50                628   49924      231     76524
# 6                 60                546   39615      215     57504
# 7                 70                485   41732      239     58773
# 8                 80                429   41860      245     57477
# 9                 90                391   32881      199     45469
# 10               100                360   33513      206     46373
# 11               110                333  136860      835    196759
# 12               120                312   75372      487    107561
