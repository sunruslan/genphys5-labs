# %% [markdown]
# # Лабораторная работа №5.6.1
# ## Исследование резонансного поглощения $\gamma$ - квантов (эффект Мессбауэра)
# *С помощью метода доплеровского сдвига мессбауэровской лилнии погложения исследуется резонансное поглощение $\gamma$-лучей, испускаемых ядрами олова $^{119}Sn$ в соединении $BaSnO_3$ при комнатной температуре. Определяется положение максимума резонансного поглощения, его величина, а также экспериментальная ширина линии $\gamma_{экс}$. Оценивается время жизни возбужденного состояния ядра $^{119}Sn$.*
# ### Теоретическая справка
# Нуклоны, как электроны могут находиться в основном и возбужденном состояниях. Переход на более низкий энергетический уровень сопровождается возникновение гамма-кванта. Все возбужденные атомы имеют конечную ширину $$\Gamma \tau \approx \frac{h}{2\pi}$$ Ядра атомов могут и поглозать гамма-кванты. Если энергия гамма-кванта равна разности между основным и возбужденным состояниями, то атом можно так возбудить(резонансный характер). Проблема возникает из-за того, что часть энергии уносит с собой ядро в качестве отдачи. Энергия отдачи: $$R = \frac{p^2}{M_я} = \frac{E_{\gamma}^2}{2M_яc^2}$$ Резонансное поглощение возможно при $$2R \leq \Gamma$$. Для наблюдения нужно воспользоваться эффектом Доплера. Скомпенсируем энергетический сдвиг 2R. Тогда поглощающие и излучающие ядра должны двигаться друг относительно друга со скоростью $$V = c\cdot R/E_{\gamma}$$ Ширина линии испускания складывается из собственной ширины линии и ее доплеровской ширины. Доплеровская ширина: $$D = \frac{v}{c} \approx \frac{v}{c}E_0$$
# $$v = \sqrt{k_Б T/M_я}$$
# $$D = 2\sqrt{Rk_Б T}$$
# Доплеровская ширина линии значительно превосходит собственную и иногда оказывается больше R.
#
# Процесс поглощения и испускания.
# 1. Энергия отдачи превышает энергию связи ядра в решетке. При этом свзь ядра становится малосущественной и никаких новых явлений не наступает. Большая энергия гамма-квантов.
# 2. При энергии гамма-квантов с E < 1 МэВ энергия отдачи оказывается недостаточной для вырывания ядра из кристаллической решетки, а импульс передается всему кристаллу. Возникают звуковые колебания(фононы).
#
# Испускание и поглощение $\gamma$-квантов в твердых телах без рождения фононов называется **эффектом Мессбауэра**. Вероятность эффекта $$f = \exp{-4\pi^2<u^2>/\lambda^2}$$
# Эффект ограничен областью малых энергий (200кэВ).
# <img src="схема.png">
# ### Измерение спектра источника
# *Цель этого этапа работы — подобрать настройки анализатора импульсов так, чтобыдетектировались только гамма-кванты с энергией 23.8 кэВ, исходящие от источника $^{119}Sn$.*
#
# Время накопления данных - 5 секунд.
#
# Ширина окна - 0.5 В.
#
# <table><tr>
#
# <td> <img src="img1.png" height="100" width="200"> </td>
#
# <td> <img src="gr0.png"></td>
#
# </tr></table>
#
# ### Анализ спектра и настройка анализатора спектра
# *Цель этого этапа работы — подобрать настройки анализатора импульсов так, чтобы детектировались только гамма-кванты с энергией 23.8 кэВ, исходящие от источника $^{119}Sn$.*
#
# LU = 2.0 В
#
# UL = 5.0 В
#
# *По окончании этого этапа электронная схема нашей установки настроена так, что подсчитываются только гамма-кванты энергиями, соответствующими используемому источнику.*
# ### Измерение резонансного поглощения
# *Необходимо измерить резонансное поглощение для четырёх образцов. Рекомендуется исследовать образцы в следующей последовательности: образец №1 (металлическое олово минимальной толщины), образец №4 (SnO2), затем образцы №2 и №3 (металлическое олово другой толщины). Параметры образцов указаны на столах. Переключение образца производится при неподвижном приводе.*
#
# Ход поглотителя $8.77\pm 0.02 мм$
#
# Время измерения - 20 сек.
#
# Таблица положений и толщин поглотителей, находящихся в держателе:
#
# |    Положение держателя    	|     1    	|     2    	|     3    	| 4    	|
# |:-------------------------:	|:--------:	|:--------:	|:--------:	|------	|
# | Толщина поглотителя (мкм) 	| 100 (Sn) 	| 200 (Sn) 	| 330 (Sn) 	| SnO2 	|
#
# Измерение фона разными образцами
#
# |    Положение держателя    	|     1    	|     2    	|     3    	| 4    	|
# |:-------------------------:	|:--------:	|:--------:	|:--------:	|------	|
# | Количество частиц в секунду 	| 58 	| 93,5 	| 86,9 	| 84,4 	|
#
#
# #### Первый образец
# <table><tr>
#
# <td> <img src="tbl1.png"></td>
#
# <td> <img src="gr1.png"></td>
#
# </tr></table>
#
# Амплитуда резонансного поглощения:
# $$\epsilon = (11\pm2)\%$$
#
# Химический сдвиг:
# $$v = (2.4\pm0.1)\text{мм/с}$$
# $$E = (19\pm1)\cdot10^{-8}\text{эВ}$$
#
# Ширина линии:
# $$\Gamma = (1.4\pm0.2)\text{мм/с} = (11\pm0.5)\cdot10^{-8}\text{эВ}$$
#
# #### Второй образец
# <table><tr>
#
# <td> <img src="tbl2.png"></td>
#
# <td> <img src="gr22.png"></td>
#
# </tr></table>
#
# Амплитуда резонансного поглощения:
# $$\epsilon = (16\pm3)\%$$
#
# Химический сдвиг:
# $$v = (2.4\pm0.1)\text{мм/с}$$
# $$E = (19\pm1)\cdot10^{-8}\text{эВ}$$
#
# Ширина линии:
# $$\Gamma = (1.3\pm0.2)\text{мм/с} = (11\pm0.5)\cdot10^{-8}\text{эВ}$$
#
# #### Третий образец
# <table><tr>
#
# <td> <img src="tbl3.png"></td>
#
# <td> <img src="gr3.png"></td>
#
# </tr></table>
#
# Амплитуда резонансного поглощения:
# $$\epsilon = (17\pm2)\%$$
#
# Химический сдвиг:
# $$v = (2.4\pm0.1)\text{мм/с}$$
# $$E = (19\pm1)\cdot10^{-8}\text{эВ}$$
#
# Ширина линии:
# $$\Gamma = (1.4\pm0.3)\text{мм/с} = (11\pm0.5)\cdot10^{-8}\text{эВ}$$
#
# #### Четвертый образец
# <table><tr>
#
# <td> <img src="tbl4.png"></td>
#
# <td> <img src="gr4.png"></td>
#
# </tr></table>
#
# Амплитуда резонансного поглощения:
# $$\epsilon = (26\pm2)\%$$
#
# Химический сдвиг = 0.
#
# Ширина линии:
# $$\Gamma = (2.2\pm0.2)\text{мм/с} = (17\pm0.5)\cdot10^{-8}\text{эВ}$$
#
# Для сравения изобразим все на одном графике.
#
# <img src="gr5.png">
#
# $$\Gamma_{теор} = 3\cdot10^{-8}\text{эВ}$$
#
# ### Вывод
# Изучили резонансное погложение гамма-квантов в кристаллах олова разной толщины и в образце $SnO_2$. При увеличении толщины поглотителя ширина линии поглощения уменьшается, можно более точно определить мксимум поглощения. Для кристалла оксида олова максимум поглощения смещен. Это происходит из-за влияние внутренних магнитный полей электронных оболочек атомов соединения.

# %%
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data0= pd.read_csv('dataset1', sep=' ', header=None)
data0.columns = [r'$Нижний порог, В$', r'$Интенсивность, \frac{частиц}{сек}$']
data0
# Out:
#     $Нижний порог, В$  $Интенсивность, \frac{частиц}{сек}$
# 0                 0.0                                 41.0
# 1                 0.5                                 78.8
# 2                 1.0                                127.2
# 3                 1.5                                  7.0
# 4                 2.0                                 13.6
# 5                 2.5                                 27.0
# 6                 3.0                                 42.0
# 7                 3.5                                 44.6
# 8                 4.0                                 42.0
# 9                 4.5                                 21.6
# 10                5.0                                  8.4
# 11                5.5                                  5.0
# 12                6.0                                  2.2
# 13                6.5                                  2.0
# 14                7.0                                  2.2
# ...

# %%
plt.figure(figsize=(8,5))
plt.errorbar(list(data0.iloc[:, 0]), list(data0.iloc[:, 1]), yerr=np.sqrt(data0.iloc[:, 1]*5)/5., fmt='-b', ecolor='g')
plt.axvline(x=2)
plt.axvline(x=5)
plt.axvline(x=7, c='r')
plt.grid()
plt.ylim(bottom=0)
plt.title(u'Спектр излучения источника', fontsize=28)
plt.xlabel(u'V, В', fontsize=20)
plt.ylabel(u'N', fontsize=20)
plt.savefig('gr11')
plt.show()

# %%
data1 = pd.read_csv('dataset2', sep=' ', header=None)
data1.columns = [r'$v-, мм/с$', r'$I-, частиц/с$', r'$v+, мм/с$', r'$I+, частиц/с$']
data1
# Out:
#     $v-, мм/с$  $I-, частиц/с$  $v+, мм/с$  $I+, частиц/с$
# 0         4.88           848.6        5.20           849.9
# 1         4.33           864.4        4.58           884.2
# 2         3.57           855.0        3.80           843.2
# 3         2.76           849.5        2.94           801.8
# 4         1.81           854.4        1.95           807.0
# 5         0.64           846.8        0.71           857.5
# 6         2.10           853.3        2.24           771.4
# 7         2.40           857.9        2.56           751.1
# 8         2.91           846.2        3.10           823.0
# 9         2.64           854.2        2.82           774.6
# 10        2.52           851.5        2.69           772.3
# 11        2.95           856.5        3.16           819.0
# 12        2.66           856.6        2.84           776.4

# %%
plt.figure(figsize=(5,5))
plt.plot(list(-1*data1.iloc[:, 0]), list(data1.iloc[:, 1]), 'b*')
plt.plot(list(data1.iloc[:, 2]), list(data1.iloc[:, 3]), 'b*')
plt.grid()
plt.xlabel(u'v, мм/с', fontsize=20)
plt.ylabel(u'I частиц/с', fontsize=20)
plt.savefig('gr1')
plt.show()

# %%
data2 = pd.read_csv('dataset3', sep=' ', header=None)
data2.columns = [r'$v-, мм/с$', r'$I-, частиц/с$', r'$v+, мм/с$', r'$I+, частиц/с$']
display(data2)
plt.figure(figsize=(5,5))
plt.plot(list(-1*data2.iloc[:, 0]), list(data2.iloc[:, 1]), 'b*')
plt.plot(list(data2.iloc[:, 2]), list(data2.iloc[:, 3]), 'b*')
plt.grid()
plt.xlabel(u'v, мм/с', fontsize=20)
plt.ylabel(u'I частиц/с', fontsize=20)
plt.savefig('gr2')
plt.show()
# Out:
#    $v-, мм/с$  $I-, частиц/с$  $v+, мм/с$  $I+, частиц/с$
# 0        4.83           400.6        5.16           394.4
# 1        4.30           395.3        4.56           394.2
# 2        3.59           397.1        3.81           391.1
# 3        2.73           398.5        2.93           357.5
# 4        1.80           404.9        1.93           372.0
# 5        0.64           392.6        0.73           394.8
# 6        2.30           402.7        2.47           335.4
# 7        2.53           394.0        2.69           337.9
# 8        2.06           395.5        2.21           341.8

# %%
data3 = pd.read_csv('dataset4', sep=' ', header=None)
data3.columns = [r'$v-, мм/с$', r'$I-, частиц/с$', r'$v+, мм/с$', r'$I+, частиц/с$']
display(data3)
plt.figure(figsize=(5,5))
plt.plot(list(-1*data3.iloc[:, 0]), list(data3.iloc[:, 1]), 'b*')
plt.plot(list(data3.iloc[:, 2]), list(data3.iloc[:, 3]), 'b*')
plt.grid()
plt.xlabel(u'v, мм/с', fontsize=20)
plt.ylabel(u'I частиц/с', fontsize=20)
plt.savefig('gr3')
plt.show()
# Out:
#    $v-, мм/с$  $I-, частиц/с$  $v+, мм/с$  $I+, частиц/с$
# 0        4.82           208.8        5.12           213.1
# 1        4.24           208.7        4.52           212.4
# 2        3.45           217.9        3.66           203.3
# 3        2.87           213.9        3.07           192.9
# 4        1.94           222.3        2.08           193.8
# 5        0.98           212.2        1.08           212.9
# 6        2.24           210.9        2.40           184.7
# 7        2.51           207.8        2.66           179.5
# 8        2.21           204.8        2.35           184.5
# 9        2.61           212.7        2.79           187.7

# %%
data4 = pd.read_csv('dataset5', sep=' ', header=None)
data4.columns = [r'$v-, мм/с$', r'$I-, частиц/с$', r'$v+, мм/с$', r'$I+, частиц/с$']
display(data4)
plt.figure(figsize=(5,5))
plt.plot(list(-1*data4.iloc[:, 0]), list(data4.iloc[:, 1]), 'b*')
plt.plot(list(data4.iloc[:, 2]), list(data4.iloc[:, 3]), 'b*')
plt.grid()
plt.xlabel(u'v, мм/с', fontsize=20)
plt.ylabel(u'I частиц/с', fontsize=20)
plt.savefig('gr4')
plt.show()
# Out:
#    $v-, мм/с$  $I-, частиц/с$  $v+, мм/с$  $I+, частиц/с$
# 0        4.89           780.7        5.22           772.5
# 1        3.25           765.4        4.51           776.9
# 2        3.69           757.0        3.94           779.1
# 3        2.81           760.5        3.00           762.1
# 4        1.80           729.6        1.92           735.4
# 5        0.87           642.0        0.96           658.0
# 6        0.64           593.4        0.73           621.9
# 7        1.09           665.9        1.20           684.0
# 8        0.55           584.2        0.61           603.4

# %%
plt.figure(figsize=(10,10))
plt.plot(list(-1*data1.iloc[:, 0]), list(data1.iloc[:, 1]), 'b*')
plt.plot(list(data1.iloc[:, 2]), list(data1.iloc[:, 3]), 'b*')
plt.plot(list(-1*data2.iloc[:, 0]), list(data2.iloc[:, 1]), 'g*')
plt.plot(list(data2.iloc[:, 2]), list(data2.iloc[:, 3]), 'g*')
plt.plot(list(-1*data3.iloc[:, 0]), list(data3.iloc[:, 1]), 'r*')
plt.plot(list(data3.iloc[:, 2]), list(data3.iloc[:, 3]), 'r*')
plt.plot(list(-1*data4.iloc[:, 0]), list(data4.iloc[:, 1]), 'y*')
plt.plot(list(data4.iloc[:, 2]), list(data4.iloc[:, 3]), 'y*')
plt.axvline(x = 2.52)
plt.grid()
plt.xlabel(u'v, мм/с', fontsize=20)
plt.ylabel(u'I частиц/с', fontsize=20)
plt.savefig('gr5')
plt.show()
